# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajkumar200409/Rajkumar-mindful/blob/main/BigMart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#connect the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import the test dataset
import pandas as pd
testset = pd.read_csv('/content/Test (1).csv')

# %%
#import the Traindataset
import pandas as pd
trainset = pd.read_csv('/content/Train (2).csv')

# %%
#import libraries
import numpy as np

# %%
 #display shapes of the dataset
 trainset . shape
# Out:
# (8523, 12)

# %%
#display shapes of the testdataset
testset . shape
# Out:
# (5681, 11)

# %%
#display data type of each column
trainset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#display data set type
testset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
#display column names
trainset.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#display  column names
testset.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
#display the information
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#display the test set information
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
#sum of the null values
trainset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#sum of the null values
testset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#display discriptive statistics
trainset.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
#display discriptive statistics
testset.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
trainset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
testset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
#trainset's head
trainset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
#testset's head
testset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
trainset.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
testset.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1

# %%
trainset['Item_Fat_Content'].values
# Out:
# array(['Low Fat', 'Regular', 'Low Fat', ..., 'Low Fat', 'Regular',
#        'Low Fat'], dtype=object)

# %%
testset['Item_Fat_Content'].values
# Out:
# array(['Low Fat', 'reg', 'Low Fat', ..., 'Low Fat', 'Regular', 'Regular'],
#       dtype=object)

# %%
trainset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
testset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt #using graaphical representation
import seaborn as sns #data visualization
from matplotlib import colors

# %%
trainset['Item_Fat_Content'].replace(['LF','reg','low fat'],['Low Fat','Regular','Low Fat'],inplace=True)
#to convert catacorical value(itmfatcontent) --LF,Reg

# %%
trainset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content',data=trainset)
plt.xlabel('Item_Fat_Content')
plt.show()
#draw the countplot ] [here low fat are high and reglar is low]

# %%
testset['Item_Fat_Content'].replace(['LF','reg','low fat'],['Low Fat','Regular','Low Fat'],inplace=True)

# %%
testset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Item_Fat_Content',data=trainset)
plt.xlabel('Item_Fat_Content')
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.hist(x='Item_Fat_Content',data=trainset)
plt.xlabel('Item_Fat_Content')
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.scatter(x="Item_Fat_Content",y="Item_Outlet_Sales",data=trainset)
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(3,3))
x = trainset['Item_Weight']
y = trainset['Item_Outlet_Sales']
plt.stem(x,y)
plt.xlabel('Item_Weight')
plt.ylabel('Item_Outlet_Sales')
plt.title('Stem Plot: Item_Weight vs Item_Outlet_Sales')
plt.show()
#stem plot is to show relation bw two features

# %%
plt.figure(figsize=(5,5))
sns.countplot(y='Item_Fat_Content',data=testset)
plt.ylabel('Item_Fat_Content')
plt.show()

# %%
plt.figure(figsize=(3,3))  #declare size of a plot
sns.countplot(y='Item_Type',data=testset)#generates a vertical line for the testset
plt.ylabel('Item_Type')#label for the y axis
plt.show()

# %%
from matplotlib import colors
Outletsize = trainset['Outlet_Size'].value_counts(normalize=True) * 100#calculates the percentage distribution of each category in the 'Outlet_Size' column of the trainset DataFrame
explode = (0.3,0.3,0.3)# slice of the pie chart
colors = ('blue','pink','red')
plt.pie(Outletsize,labels = Outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('% of Outlet_Size')
plt.axis('equal')
plt.show()

# %% [markdown]
# HANDLING MISSING VALUES AND CATA VALUES

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()#transform cata to num
for col in trainset.columns:
  if trainset[col].dtype=='object':#current type  is catagorical value
    trainset[col]=le.fit_transform(trainset[col])#to transform the num

# %%
le=LabelEncoder()#transform cata to num
for col in testset.columns:
  if testset[col].dtype=='object':#current type  is catagorical value
    testset[col]=le.fit_transform(testset[col])#to transform the num

# %%
imputer=SimpleImputer(strategy='median')#used for filli the missing value
mis_cols=['Item_Weight','Outlet_Size']
trainset[mis_cols]=imputer.fit_transform(trainset[mis_cols])#replaing the missing value

# %%
imputer=SimpleImputer(strategy='mean')
mis_cols=['Item_Weight','Outlet_Size']
testset[mis_cols]=imputer.fit_transform(testset[mis_cols])

# %%
# Visulaizing the Normal distribution plot using the seaborn library for the Item_MRP column.
sns.distplot(a=trainset['Item_Outlet_Sales'], kde=True, rug=True)

# Set the title and labels for the plot
plt.title('Distribution Plot of Item_MRP')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Density')

# Show the plot
plt.show()
# Out:
# <ipython-input-45-c061a1c45f06>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=trainset['Item_Outlet_Sales'], kde=True, rug=True)

# %% [markdown]
# HANDLING OUTIERS

# %%
x=trainset.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(4,4))
x.boxplot(ax=ax,vert=False,color="green")
plt.title('numerical features')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
q1=np.percentile(trainset['Item_Outlet_Sales'],25)
q2=np.percentile(trainset['Item_Outlet_Sales'],75)
iqr=q2-q1
print()

# %%
sublist=trainset[['Item_Fat_Content','Item_Outlet_Sales','Outlet_Type','Outlet_Location_Type']]
corr=sublist.corr()
mask=np.triu(np.ones_like(corr,dtype=bool))
fig,ax=plt.subplots(figsize=(6,6))
sns.heatmap(corr,annot=True,cmap=sns.diverging_palette(20,220,n=200),square=True,center=0,linewidths=0.5,cbar_kws={"shrink":0.5})
plt.title('correlation heatup')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming trainset is your DataFrame containing the data
sublist = trainset[['Item_Fat_Content', 'Item_Outlet_Sales', 'Outlet_Type', 'Outlet_Size', 'Item_Type', 'Outlet_Location_Type', 'Outlet_Establishment_Year', 'Item_Visibility']]

# Encode categorical variables
sublist_encoded = pd.get_dummies(sublist)

# Calculate correlation matrix
corr = sublist_encoded.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Plotting the heatmap
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, square=True, linewidths=0.5, cbar_kws={'shrink': 0.5}, mask=mask)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.distplot(a=testset['Item_Weight'],kde=True,rug=True)
plt.title('Distribution of Item Weight')
plt.xlabel('Item_Weight')
plt.show()
# Out:
# <ipython-input-50-8042fc30e296>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=testset['Item_Weight'],kde=True,rug=True)

# %%
x=testset.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(5,5))
x.boxplot(ax=ax,vert=False,color ='Blue')
plt.title('Boxplot of Numerical Features')
plt.show()

# %%
Q1=np.percentile(testset['Item_Weight'],25)
Q3=np.percentile(testset['Item_Weight'],75)
iqr=Q3-Q1
print(iqr,Q1,Q3)
# Out:
# 6.654999999999999 9.195 15.85

# %%
testset['Square_Root']=np.cbrt(testset['Item_MRP'])

# %%
sns.distplot(a=testset['Square_Root'],kde=True,rug=True)
plt.title('Distribution of Item Weight')
plt.xlabel('Item_Weight')
plt.show()
# Out:
# <ipython-input-54-1f5ae4cf3286>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=testset['Square_Root'],kde=True,rug=True)

# %%
sns.distplot(a=testset['Item_MRP'],kde=True,rug=True)
plt.title('Distribution of Item Mrp')
plt.xlabel('Item_MRP')
plt.show()
# Out:
# <ipython-input-55-cea065e92095>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=testset['Item_MRP'],kde=True,rug=True)

# %%
sns.distplot(a=testset['Item_Visibility'],kde=True,rug=True)
plt.title('Distribution of Item Visibility')
plt.xlabel('Item_Visibility')
plt.show()
# Out:
# <ipython-input-56-0d15a3d68f91>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=testset['Item_Visibility'],kde=True,rug=True)

# %% [markdown]
# FEATURE ENGINEERING

# %%
trainset['Outlet_Age']=trainset['Outlet_Establishment_Year'].apply(lambda year: 2020 - year)

# %%
testset['Outlet_Age']=testset['Outlet_Establishment_Year'].apply(lambda year: 2020 - year)

# %%
trainset=trainset.drop(['Item_Type','Outlet_Establishment_Year','Outlet_Identifier','Item_Identifier'],axis=1)

# %%
testset=testset.drop(['Item_Type','Outlet_Establishment_Year','Outlet_Identifier','Item_Identifier'],axis=1)

# %%
trainset=trainset.drop(['Item_Visibility'],axis=1)

# %%
testset=testset.drop(['Item_Visibility'],axis=1)

# %%
testset.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_MRP  Outlet_Size  Outlet_Location_Type  \
# 0    20.750000                 0  107.8622          1.0                     0
# 1     8.300000                 1   87.3198          3.0                     1
# 2    14.600000                 0  241.7538          3.0                     2
# 3     7.315000                 0  155.0340          3.0                     1
# 4    12.695633                 1  234.2300          1.0                     2
#
#    Outlet_Type  Square_Root  Outlet_Age
# 0            1     4.760177          21
# 1            1     4.436470          13
# 2            0     6.229566          22
# 3            1     5.372078          13
# 4            3     6.164258          35

# %%
trainset.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_MRP  Outlet_Size  Outlet_Location_Type  \
# 0         9.30                 0  249.8092          1.0                     0
# 1         5.92                 1   48.2692          1.0                     2
# 2        17.50                 0  141.6180          1.0                     0
# 3        19.20                 1  182.0950          3.0                     2
# 4         8.93                 0   53.8614          0.0                     2
#
#    Outlet_Type  Item_Outlet_Sales  Outlet_Age
# 0            1          3735.1380          21
# 1            2           443.4228          11
# 2            1          2097.2700          21
# 3            0           732.3800          22
# 4            1           994.7052          33

# %% [markdown]
# STANDARDION FEATURES SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=trainset.iloc[:,:11]
y=trainset['Item_Outlet_Sales']

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)
x=pd.DataFrame(x)

# %%
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.831187 -0.738147  1.747454 -0.744458 -1.369334 -0.252658  0.910601
# 1 -1.630810  1.354743 -1.489023 -0.744458  1.091569  1.002972 -1.018440
# 2  1.108727 -0.738147  0.010040 -0.744458 -1.369334 -0.252658 -0.049238
# 3  1.510904  1.354743  0.660050  1.277535  1.091569 -1.508289 -0.849103
# 4 -0.918719 -0.738147 -1.399220 -1.755454  1.091569 -0.252658 -0.695373
#
#           7
# 0 -0.139541
# 1 -1.334103
# 2 -0.139541
# 3 -0.020085
# 4  1.293934

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
testset.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_MRP  Outlet_Size  Outlet_Location_Type  \
# 0    20.750000                 0  107.8622          1.0                     0
# 1     8.300000                 1   87.3198          3.0                     1
# 2    14.600000                 0  241.7538          3.0                     2
# 3     7.315000                 0  155.0340          3.0                     1
# 4    12.695633                 1  234.2300          1.0                     2
#
#    Outlet_Type  Square_Root  Outlet_Age
# 0            1     4.760177          21
# 1            1     4.436470          13
# 2            0     6.229566          22
# 3            1     5.372078          13
# 4            3     6.164258          35

# %%
from sklearn.preprocessing import StandardScaler

# %%
a=testset.iloc[:,:11]# slicing the testset
b=testset['Square_Root']

# %%
scaler=StandardScaler()#initialize  a standardization
a=scaler.fit_transform(a)#compute mean and standard deviation
a=pd.DataFrame(a)#This converts the standardized numpy array x back into a pandas DataFrame.

# %%
a.head()
# Out:
#               0         1         2         3         4         5         6  \
# 0  1.897460e+00 -0.740811 -0.536555 -0.744484 -1.369215 -0.252769 -0.383554
# 1 -1.035530e+00  1.349873 -0.868937  1.277707 -0.138827 -0.252769 -0.775426
# 2  4.486336e-01 -0.740811  1.629848  1.277707  1.091560 -1.507994  1.395257
# 3 -1.267578e+00 -0.740811  0.226697  1.277707 -0.138827 -0.252769  0.357201
# 4  4.184768e-16  1.349873  1.508110 -0.744484  1.091560  2.257683  1.316197
#
#           7
# 0 -0.139891
# 1 -1.095512
# 2 -0.020438
# 3 -1.095512
# 4  1.532446

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           8523 non-null   float64
#  1   Item_Fat_Content      8523 non-null   int64
#  2   Item_MRP              8523 non-null   float64
#  3   Outlet_Size           8523 non-null   float64
#  4   Outlet_Location_Type  8523 non-null   int64
#  5   Outlet_Type           8523 non-null   int64
#  6   Item_Outlet_Sales     8523 non-null   float64
#  7   Outlet_Age            8523 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 532.8 KB

# %%
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           5681 non-null   float64
#  1   Item_Fat_Content      5681 non-null   int64
#  2   Item_MRP              5681 non-null   float64
#  3   Outlet_Size           5681 non-null   float64
#  4   Outlet_Location_Type  5681 non-null   int64
#  5   Outlet_Type           5681 non-null   int64
#  6   Square_Root           5681 non-null   float64
#  7   Outlet_Age            5681 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 355.2 KB

# %% [markdown]
# BUILDING THE MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x)

# %%
print('R-Square value on the training set:=', lr.score(x,y))
print('-------------------------------')
# Out:
# R-Square value on the training set:= 1.0
# -------------------------------

# %%
scores = cross_val_score(lr, x, y, cv=5)

# %%
print('CV R-squared scores:',scores,'\n')
print('Average CV R-squared score:',np.mean(scores),'\n')
# Out:
# CV R-squared scores: [1. 1. 1. 1. 1.]
#
# Average CV R-squared score: 1.0

# %%
print('MSE on the traning set: = ',MSE(y,y_pred))
print('MAE on the traning set: = ',MAE(y,y_pred))
# Out:
# MSE on the traning set: =  7.29875607844421e-25
# MAE on the traning set: =  6.873265042624499e-13

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
